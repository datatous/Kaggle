# %% [markdown]
# ## Kaggle Playground S6E1 - Predicting Student Test Scores
#
# This notebook performs **reproducible EDA, preprocessing, cross-validation, ensembling (blending), and submission file generation** in one place.
#
# - **Target**: `exam_score`
# - **Metric (local validation)**: RMSE (lower is better)
#
# > Note: Kaggle Public/Private LB can differ from CV; final decisions are based on **OOF performance**.

# %%
# Core libraries
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.optimize import minimize

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

from sklearn.linear_model import Ridge
from sklearn.ensemble import HistGradientBoostingRegressor

# Additional models for ensemble
try:
    import xgboost as xgb
    XGBOOST_AVAILABLE = True
except ImportError:
    XGBOOST_AVAILABLE = False
    print("XGBoost not available, skipping XGBoost model")

try:
    import lightgbm as lgb
    LIGHTGBM_AVAILABLE = True
except ImportError:
    LIGHTGBM_AVAILABLE = False
    print("LightGBM not available, skipping LightGBM model")

# Hyperparameter tuning
try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False
    print("Optuna not available, using default hyperparameters")

warnings.filterwarnings('ignore')

# Reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# Matplotlib Korean font settings (for local environments)
import platform
system_name = platform.system()
if system_name == 'Windows':
    plt.rc('font', family='Malgun Gothic')
elif system_name == 'Darwin':  # Mac
    plt.rc('font', family='AppleGothic')
else:  # Linux (Colab, Docker)
    plt.rc('font', family='NanumGothic')
plt.rc('axes', unicode_minus=False)

# Path resolution: try several options (including Kaggle)
def find_data_dir():
    """Find data directory that works both locally and on Kaggle."""
    # Kaggle competition dataset
    kaggle_dir = Path('/kaggle/input/playground-series-s6e1')
    if kaggle_dir.exists() and (kaggle_dir / 'train.csv').exists():
        return kaggle_dir

    possible_paths = [
        Path('Predicting Student Test Scores/data'),  # from project root
        Path('data'),  # data folder next to this notebook
        Path('../data'),  # parent-level data folder
        Path('.').resolve() / 'Predicting Student Test Scores' / 'data',  # absolute path guess
    ]

    for path in possible_paths:
        if path.exists() and (path / 'train.csv').exists():
            return path

    # As a last resort, walk up parents and try to find the data folder
    cwd = Path.cwd()
    for parent in [cwd] + list(cwd.parents):
        candidate = parent / 'Predicting Student Test Scores' / 'data'
        if candidate.exists() and (candidate / 'train.csv').exists():
            return candidate

    # Fallback (will raise an error later if files are missing)
    return Path('Predicting Student Test Scores/data')

DATA_DIR = find_data_dir()
TRAIN_PATH = DATA_DIR / 'train.csv'
TEST_PATH = DATA_DIR / 'test.csv'
SAMPLE_SUB_PATH = DATA_DIR / 'sample_submission.csv'

print(f'Current working directory: {Path.cwd()}')
print(f'Data directory: {DATA_DIR.resolve()}')
print(f'TRAIN path exists: {TRAIN_PATH.exists()}')
TRAIN_PATH, TEST_PATH, SAMPLE_SUB_PATH
# Out:
# /usr/local/lib/python3.12/dist-packages/sqlalchemy/orm/query.py:195: SyntaxWarning: "is not" with 'tuple' literal. Did you mean "!="?
#   if entities is not ():
# Current working directory: /kaggle/working
# Data directory: /kaggle/input/playground-series-s6e1
# TRAIN path exists: True
# (PosixPath('/kaggle/input/playground-series-s6e1/train.csv'),
#  PosixPath('/kaggle/input/playground-series-s6e1/test.csv'),
#  PosixPath('/kaggle/input/playground-series-s6e1/sample_submission.csv'))

# %%
# Data loading (wrap in try-except for robustness)
try:
    train_df = pd.read_csv(TRAIN_PATH)
    test_df = pd.read_csv(TEST_PATH)
    sample_sub = pd.read_csv(SAMPLE_SUB_PATH)
except FileNotFoundError as e:
    raise FileNotFoundError(
        f"File not found. Please check paths.\n- TRAIN: {TRAIN_PATH}\n- TEST: {TEST_PATH}\n- SAMPLE: {SAMPLE_SUB_PATH}"
    ) from e

print('train:', train_df.shape, 'test:', test_df.shape)
display(train_df.head())
display(test_df.head())
display(sample_sub.head())
# Out:
# train: (630000, 13) test: (270000, 12)
#    id  age  gender   course  study_hours  class_attendance internet_access  \
# 0   0   21  female     b.sc         7.91              98.8              no
# 1   1   18   other  diploma         4.95              94.8             yes
# 2   2   20  female     b.sc         4.68              92.6             yes
# 3   3   19    male     b.sc         2.00              49.5             yes
# 4   4   23    male      bca         7.65              86.9             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0          4.9       average  online videos             low            easy
# 1          4.7          poor     self-study          medium        moderate
# 2          5.8          poor       coaching            high        moderate
# 3          8.3       average    group study            high        moderate
# 4          9.6          good     self-study            high            easy
#
#    exam_score
# ...

# %%
# Basic data quality checks (missing/duplicates/dtypes)
TARGET_COL = 'exam_score'
ID_COL = 'id'

assert TARGET_COL in train_df.columns, 'Target column is missing in train.'
assert TARGET_COL not in test_df.columns, 'Target column is present in test (data leakage)!'

print('--- Dtypes ---')
display(train_df.dtypes)

print('--- Missing values (train) ---')
display(train_df.isna().mean().sort_values(ascending=False).to_frame('missing_rate'))

print('--- Missing values (test) ---')
display(test_df.isna().mean().sort_values(ascending=False).to_frame('missing_rate'))

print('--- Duplicates ---')
print('train duplicate rows:', train_df.duplicated().sum())
print('test duplicate rows:', test_df.duplicated().sum())

# Target distribution
plt.figure(figsize=(8, 4))
sns.histplot(train_df[TARGET_COL], bins=50, kde=True)
plt.title('Target (exam_score) distribution')
plt.xlabel('exam_score')
plt.ylabel('count')
plt.show()
# Out:
# --- Dtypes ---
# id                    int64
# age                   int64
# gender               object
# course               object
# study_hours         float64
# class_attendance    float64
# internet_access      object
# sleep_hours         float64
# sleep_quality        object
# study_method         object
# facility_rating      object
# exam_difficulty      object
# exam_score          float64
# dtype: object
# --- Missing values (train) ---
#                   missing_rate
# id                         0.0
# age                        0.0
# gender                     0.0
# course                     0.0
# study_hours                0.0
# class_attendance           0.0
# internet_access            0.0
# sleep_hours                0.0
# sleep_quality              0.0
# study_method               0.0
# facility_rating            0.0
# exam_difficulty            0.0
# exam_score                 0.0
# --- Missing values (test) ---
#                   missing_rate
# ...

# %%
# Quick EDA: numeric / categorical summaries
feature_cols = [c for c in train_df.columns if c not in [TARGET_COL]]

X = train_df[feature_cols].copy()
y = train_df[TARGET_COL].copy()
X_test = test_df[feature_cols].copy()

# Split column types
categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
numeric_cols = [c for c in X.columns if c not in categorical_cols]

print('numeric_cols:', numeric_cols)
print('categorical_cols:', categorical_cols)

print('\n--- Numeric summary ---')
display(train_df[numeric_cols + [TARGET_COL]].describe().T)

print('\n--- Categorical cardinality ---')
display(train_df[categorical_cols].nunique().sort_values(ascending=False).to_frame('n_unique'))

# Correlation (numeric only) - use a sample for speed
sample_df = train_df.sample(n=min(50_000, len(train_df)), random_state=RANDOM_STATE)
plt.figure(figsize=(10, 6))
sns.heatmap(sample_df[numeric_cols + [TARGET_COL]].corr(), annot=False, cmap='coolwarm', center=0)
plt.title('Numeric correlations (sample)')
plt.show()
# Out:
# numeric_cols: ['id', 'age', 'study_hours', 'class_attendance', 'sleep_hours']
# categorical_cols: ['gender', 'course', 'internet_access', 'sleep_quality', 'study_method', 'facility_rating', 'exam_difficulty']
#
# --- Numeric summary ---
#                      count           mean            std     min        25%  \
# id                630000.0  314999.500000  181865.479132   0.000  157499.75
# age               630000.0      20.545821       2.260238  17.000      19.00
# study_hours       630000.0       4.002337       2.359880   0.080       1.97
# class_attendance  630000.0      71.987261      17.430098  40.600      57.00
# sleep_hours       630000.0       7.072758       1.744811   4.100       5.60
# exam_score        630000.0      62.506672      18.916884  19.599      48.80
#
#                        50%        75%        max
# id                314999.5  472499.25  629999.00
# age                   21.0      23.00      24.00
# study_hours            4.0       6.05       7.91
# ...

# %%
# Feature engineering: derived features (v2)
# Add interaction terms and ratios that might be informative

def add_derived_features(df):
    """Add derived features to the dataframe."""
    df = df.copy()
    
    # Study efficiency: study_hours per class_attendance
    df['study_efficiency'] = df['study_hours'] / (df['class_attendance'] + 1e-6)
    
    # Sleep-study balance
    df['sleep_study_ratio'] = df['sleep_hours'] / (df['study_hours'] + 1e-6)
    
    # Total engagement: study_hours + class_attendance (normalized)
    df['total_engagement'] = df['study_hours'] + (df['class_attendance'] / 10.0)
    
    # Age-normalized study hours (older students might study differently)
    df['study_hours_per_age'] = df['study_hours'] / (df['age'] + 1e-6)
    
    return df

# Apply feature engineering
print("Adding derived features...")
X_enhanced = add_derived_features(X)
X_test_enhanced = add_derived_features(X_test)

# Update feature columns
feature_cols = [c for c in X_enhanced.columns if c not in [TARGET_COL]]
categorical_cols = X_enhanced.select_dtypes(include=['object']).columns.tolist()
numeric_cols = [c for c in X_enhanced.columns if c not in categorical_cols]

print(f"Original features: {len(X.columns)}")
print(f"Enhanced features: {len(X_enhanced.columns)}")
print(f"New numeric features: {set(numeric_cols) - set(X.columns)}")

# Update X and X_test
X = X_enhanced
X_test = X_test_enhanced
# Out:
# Adding derived features...
# Original features: 12
# Enhanced features: 16
# New numeric features: {'study_efficiency', 'study_hours_per_age', 'total_engagement', 'sleep_study_ratio'}

# %%
# Preprocessing pipelines (v2: updated after feature engineering)
# - Linear model: OneHotEncoder + StandardScaler(with_mean=False) on sparse matrix
# - Tree model: OrdinalEncoder(unknown=-1) for fast and memory-efficient handling

# Note: numeric_cols and categorical_cols are now updated after feature engineering
numeric_transformer_basic = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median')),
    ]
)

categorical_transformer_ohe = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=True)),
    ]
)

categorical_transformer_ord = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
    ]
)

preprocess_ohe = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer_basic, numeric_cols),
        ('cat', categorical_transformer_ohe, categorical_cols),
    ],
    remainder='drop',
    sparse_threshold=0.3,
)

preprocess_ord = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer_basic, numeric_cols),
        ('cat', categorical_transformer_ord, categorical_cols),
    ],
    remainder='drop',
)

# Model definitions (v2: expanded ensemble with XGBoost/LightGBM)
ridge_model = Ridge(alpha=2.0, random_state=RANDOM_STATE)

hgb_model = HistGradientBoostingRegressor(
    loss='squared_error',
    learning_rate=0.06,
    max_depth=None,
    max_leaf_nodes=63,
    min_samples_leaf=40,
    l2_regularization=0.0,
    max_bins=255,
    random_state=RANDOM_STATE,
)

# XGBoost model (if available)
if XGBOOST_AVAILABLE:
    xgb_model = xgb.XGBRegressor(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=RANDOM_STATE,
        tree_method='hist',
    )
else:
    xgb_model = None

# LightGBM model (if available)
if LIGHTGBM_AVAILABLE:
    lgb_model = lgb.LGBMRegressor(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=RANDOM_STATE,
        verbose=-1,
    )
else:
    lgb_model = None

# Pipeline definitions
model_ridge = Pipeline(
    steps=[
        ('preprocess', preprocess_ohe),
        ('scaler', StandardScaler(with_mean=False)),
        ('model', ridge_model),
    ]
)

model_hgb = Pipeline(
    steps=[
        ('preprocess', preprocess_ord),
        ('model', hgb_model),
    ]
)

# XGBoost and LightGBM use ordinal encoding (tree models)
if XGBOOST_AVAILABLE:
    model_xgb = Pipeline(
        steps=[
            ('preprocess', preprocess_ord),
            ('model', xgb_model),
        ]
    )
else:
    model_xgb = None

if LIGHTGBM_AVAILABLE:
    model_lgb = Pipeline(
        steps=[
            ('preprocess', preprocess_ord),
            ('model', lgb_model),
        ]
    )
else:
    model_lgb = None

print(f"Models available: Ridge={True}, HistGB={True}, XGBoost={XGBOOST_AVAILABLE}, LightGBM={LIGHTGBM_AVAILABLE}")
model_ridge, model_hgb
# Out:
# Models available: Ridge=True, HistGB=True, XGBoost=True, LightGBM=True
# (Pipeline(steps=[('preprocess',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(strategy='median'))]),
#                                                    ['id', 'age', 'study_hours',
#                                                     'class_attendance',
#                                                     'sleep_hours',
#                                                     'study_efficiency',
#                                                     'sleep_study_ratio',
#                                                     'total_engagement',
#                                                     'study_hours_per_age']),
#                                                   ('cat',
# ...

# %%
# CV utilities

def rmse(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))


def train_cv_oof(model, X, y, X_test, n_splits=5, random_state=RANDOM_STATE):
    """Generate OOF + test predictions with KFold.

    - OOF is the core ingredient for blending/stacking
    - test_pred is the fold-wise mean prediction
    """
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    oof_pred = np.zeros(len(X), dtype=np.float64)
    test_pred = np.zeros(len(X_test), dtype=np.float64)
    scores = []

    for fold, (tr_idx, va_idx) in enumerate(cv.split(X), start=1):
        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

        # Train model
        model.fit(X_tr, y_tr)

        # Validation prediction
        va_pred = model.predict(X_va)
        oof_pred[va_idx] = va_pred

        fold_rmse = rmse(y_va, va_pred)
        scores.append(fold_rmse)
        print(f'[fold {fold}] RMSE: {fold_rmse:.5f}')

        # Accumulate test predictions
        test_pred += model.predict(X_test) / n_splits

    print(f'CV RMSE mean: {np.mean(scores):.5f}  std: {np.std(scores):.5f}')
    print(f'OOF RMSE: {rmse(y, oof_pred):.5f}')
    return oof_pred, test_pred, scores


# Optuna hyperparameter tuning (v2)
def optimize_hyperparameters(model_name, X, y, n_trials=20, n_splits=3, random_state=RANDOM_STATE):
    """Optimize hyperparameters using Optuna with reduced CV for speed."""
    if not OPTUNA_AVAILABLE:
        print(f"Optuna not available, skipping optimization for {model_name}")
        return None
    
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    
    def objective(trial):
        if model_name == 'ridge':
            alpha = trial.suggest_float('alpha', 0.1, 10.0, log=True)
            model = Pipeline([
                ('preprocess', preprocess_ohe),
                ('scaler', StandardScaler(with_mean=False)),
                ('model', Ridge(alpha=alpha, random_state=random_state)),
            ])
        elif model_name == 'hgb':
            lr = trial.suggest_float('learning_rate', 0.01, 0.2, log=True)
            max_leaf = trial.suggest_int('max_leaf_nodes', 31, 127)
            min_samples = trial.suggest_int('min_samples_leaf', 20, 100)
            model = Pipeline([
                ('preprocess', preprocess_ord),
                ('model', HistGradientBoostingRegressor(
                    learning_rate=lr,
                    max_leaf_nodes=max_leaf,
                    min_samples_leaf=min_samples,
                    random_state=random_state,
                )),
            ])
        elif model_name == 'xgb' and XGBOOST_AVAILABLE:
            lr = trial.suggest_float('learning_rate', 0.01, 0.2, log=True)
            max_depth = trial.suggest_int('max_depth', 4, 8)
            subsample = trial.suggest_float('subsample', 0.6, 1.0)
            colsample = trial.suggest_float('colsample_bytree', 0.6, 1.0)
            model = Pipeline([
                ('preprocess', preprocess_ord),
                ('model', xgb.XGBRegressor(
                    n_estimators=200,
                    max_depth=max_depth,
                    learning_rate=lr,
                    subsample=subsample,
                    colsample_bytree=colsample,
                    random_state=random_state,
                    tree_method='hist',
                )),
            ])
        elif model_name == 'lgb' and LIGHTGBM_AVAILABLE:
            lr = trial.suggest_float('learning_rate', 0.01, 0.2, log=True)
            max_depth = trial.suggest_int('max_depth', 4, 8)
            subsample = trial.suggest_float('subsample', 0.6, 1.0)
            colsample = trial.suggest_float('colsample_bytree', 0.6, 1.0)
            model = Pipeline([
                ('preprocess', preprocess_ord),
                ('model', lgb.LGBMRegressor(
                    n_estimators=200,
                    max_depth=max_depth,
                    learning_rate=lr,
                    subsample=subsample,
                    colsample_bytree=colsample,
                    random_state=random_state,
                    verbose=-1,
                )),
            ])
        else:
            return float('inf')
        
        scores = []
        for tr_idx, va_idx in cv.split(X):
            X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
            y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]
            model.fit(X_tr, y_tr)
            va_pred = model.predict(X_va)
            scores.append(rmse(y_va, va_pred))
        
        return np.mean(scores)
    
    study = optuna.create_study(direction='minimize', study_name=f'{model_name}_opt')
    study.optimize(objective, n_trials=n_trials, show_progress_bar=False)
    
    print(f'{model_name.upper()} best params: {study.best_params}, best CV RMSE: {study.best_value:.5f}')
    return study.best_params

# %%
# Hyperparameter optimization with Optuna (v2)
# Note: This is optional and can be skipped if Optuna is not available
# For faster iteration, we use fewer trials and folds during optimization
USE_OPTUNA = OPTUNA_AVAILABLE  # Set to False to skip optimization

if USE_OPTUNA:
    print("=== Hyperparameter Optimization (Optuna) ===\n")
    
    # Optimize each model (reduced trials/folds for speed)
    best_params = {}
    
    print("Optimizing Ridge...")
    best_params['ridge'] = optimize_hyperparameters('ridge', X, y, n_trials=10, n_splits=3)
    
    print("\nOptimizing HistGB...")
    best_params['hgb'] = optimize_hyperparameters('hgb', X, y, n_trials=10, n_splits=3)
    
    if XGBOOST_AVAILABLE:
        print("\nOptimizing XGBoost...")
        best_params['xgb'] = optimize_hyperparameters('xgb', X, y, n_trials=10, n_splits=3)
    
    if LIGHTGBM_AVAILABLE:
        print("\nOptimizing LightGBM...")
        best_params['lgb'] = optimize_hyperparameters('lgb', X, y, n_trials=10, n_splits=3)
    
    # Update models with optimized parameters
    if best_params.get('ridge'):
        model_ridge = Pipeline([
            ('preprocess', preprocess_ohe),
            ('scaler', StandardScaler(with_mean=False)),
            ('model', Ridge(alpha=best_params['ridge']['alpha'], random_state=RANDOM_STATE)),
        ])
    
    if best_params.get('hgb'):
        model_hgb = Pipeline([
            ('preprocess', preprocess_ord),
            ('model', HistGradientBoostingRegressor(
                learning_rate=best_params['hgb']['learning_rate'],
                max_leaf_nodes=best_params['hgb']['max_leaf_nodes'],
                min_samples_leaf=best_params['hgb']['min_samples_leaf'],
                random_state=RANDOM_STATE,
            )),
        ])
    
    if best_params.get('xgb') and XGBOOST_AVAILABLE:
        model_xgb = Pipeline([
            ('preprocess', preprocess_ord),
            ('model', xgb.XGBRegressor(
                n_estimators=200,
                max_depth=best_params['xgb']['max_depth'],
                learning_rate=best_params['xgb']['learning_rate'],
                subsample=best_params['xgb']['subsample'],
                colsample_bytree=best_params['xgb']['colsample_bytree'],
                random_state=RANDOM_STATE,
                tree_method='hist',
            )),
        ])
    
    if best_params.get('lgb') and LIGHTGBM_AVAILABLE:
        model_lgb = Pipeline([
            ('preprocess', preprocess_ord),
            ('model', lgb.LGBMRegressor(
                n_estimators=200,
                max_depth=best_params['lgb']['max_depth'],
                learning_rate=best_params['lgb']['learning_rate'],
                subsample=best_params['lgb']['subsample'],
                colsample_bytree=best_params['lgb']['colsample_bytree'],
                random_state=RANDOM_STATE,
                verbose=-1,
            )),
        ])
    
    print("\n" + "="*50 + "\n")
else:
    print("Optuna not available, using default hyperparameters\n")
    best_params = {}


# Model training (generate OOF predictions) - v2: expanded ensemble
print('=== Ridge(OHE) ===')
ridge_oof, ridge_test, ridge_scores = train_cv_oof(model_ridge, X, y, X_test, n_splits=5)

print('\n=== HistGB(Ordinal) ===')
hgb_oof, hgb_test, hgb_scores = train_cv_oof(model_hgb, X, y, X_test, n_splits=5)

# XGBoost
if model_xgb is not None:
    print('\n=== XGBoost(Ordinal) ===')
    xgb_oof, xgb_test, xgb_scores = train_cv_oof(model_xgb, X, y, X_test, n_splits=5)
else:
    xgb_oof, xgb_test, xgb_scores = None, None, None

# LightGBM
if model_lgb is not None:
    print('\n=== LightGBM(Ordinal) ===')
    lgb_oof, lgb_test, lgb_scores = train_cv_oof(model_lgb, X, y, X_test, n_splits=5)
else:
    lgb_oof, lgb_test, lgb_scores = None, None, None

# Performance comparison (v2: all models)
results_list = [
    ('Ridge(OHE)', ridge_oof),
    ('HistGB(Ordinal)', hgb_oof),
]
if xgb_oof is not None:
    results_list.append(('XGBoost(Ordinal)', xgb_oof))
if lgb_oof is not None:
    results_list.append(('LightGBM(Ordinal)', lgb_oof))

results_df = pd.DataFrame({
    'model': [name for name, _ in results_list],
    'oof_rmse': [rmse(y, oof) for _, oof in results_list],
})
display(results_df.sort_values('oof_rmse'))
# Out:
# [I 2026-01-22 09:53:14,047] A new study created in memory with name: ridge_opt
# === Hyperparameter Optimization (Optuna) ===
#
# Optimizing Ridge...
# [I 2026-01-22 09:53:21,570] Trial 0 finished with value: 8.894037234055396 and parameters: {'alpha': 1.4341813099898}. Best is trial 0 with value: 8.894037234055396.
# [I 2026-01-22 09:53:29,194] Trial 1 finished with value: 8.894037198571368 and parameters: {'alpha': 5.221285452040284}. Best is trial 1 with value: 8.894037198571368.
# [I 2026-01-22 09:53:36,682] Trial 2 finished with value: 8.894037230934622 and parameters: {'alpha': 1.6557593907968846}. Best is trial 1 with value: 8.894037198571368.
# [I 2026-01-22 09:53:44,177] Trial 3 finished with value: 8.894037254729248 and parameters: {'alpha': 0.1487833096286331}. Best is trial 1 with value: 8.894037198571368.
# ...

# %%
# Optimal OOF-based blending (v2: multiple models)
# Use scipy.optimize for multi-model blending weights

def blend_rmse(weights, y_true, predictions_list):
    """Compute RMSE of weighted blend."""
    blend = np.zeros(len(y_true))
    for w, pred in zip(weights, predictions_list):
        blend += w * pred
    return rmse(y_true, blend)

def optimize_blend_weights(y_true, predictions_list):
    """Find optimal blending weights that minimize RMSE."""
    n_models = len(predictions_list)
    
    # Constraint: weights sum to 1
    constraints = {'type': 'eq', 'fun': lambda w: np.sum(w) - 1.0}
    # Bounds: each weight in [0, 1]
    bounds = [(0, 1) for _ in range(n_models)]
    # Initial guess: equal weights
    x0 = np.ones(n_models) / n_models
    
    result = minimize(
        lambda w: blend_rmse(w, y_true, predictions_list),
        x0,
        method='SLSQP',
        bounds=bounds,
        constraints=constraints,
    )
    
    return result.x

# Collect all available OOF predictions
oof_predictions = [ridge_oof, hgb_oof]
test_predictions = [ridge_test, hgb_test]
model_names = ['Ridge', 'HistGB']

if xgb_oof is not None:
    oof_predictions.append(xgb_oof)
    test_predictions.append(xgb_test)
    model_names.append('XGBoost')

if lgb_oof is not None:
    oof_predictions.append(lgb_oof)
    test_predictions.append(lgb_test)
    model_names.append('LightGBM')

# Optimize blending weights
optimal_weights = optimize_blend_weights(y.values, oof_predictions)

print("Optimal blending weights:")
for name, weight in zip(model_names, optimal_weights):
    print(f'  {name}: {weight:.4f}')

# Compute blended predictions
blend_oof = np.zeros(len(y))
blend_test = np.zeros(len(X_test))
for w, oof, test_pred in zip(optimal_weights, oof_predictions, test_predictions):
    blend_oof += w * oof
    blend_test += w * test_pred

# Performance summary
print('\n=== Performance Summary ===')
for name, oof_pred in zip(model_names, oof_predictions):
    print(f'{name} OOF RMSE: {rmse(y, oof_pred):.5f}')
print(f'Blend OOF RMSE: {rmse(y, blend_oof):.5f}')

# Sanity check: OOF prediction distributions
plt.figure(figsize=(12, 4))
for name, oof_pred in zip(model_names, oof_predictions):
    sns.kdeplot(oof_pred, label=f'{name} OOF', lw=2)
sns.kdeplot(blend_oof, label='Blend OOF', lw=2, linestyle='--')
plt.title('OOF prediction distribution comparison')
plt.xlabel('pred')
plt.ylabel('density')
plt.legend()
plt.show()
# Out:
# Optimal blending weights:
#   Ridge: 0.0000
#   HistGB: 0.1972
#   XGBoost: 0.4758
#   LightGBM: 0.3270
#
# === Performance Summary ===
# Ridge OOF RMSE: 8.89409
# HistGB OOF RMSE: 8.80658
# XGBoost OOF RMSE: 8.78966
# LightGBM OOF RMSE: 8.79891
# Blend OOF RMSE: 8.77854
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# ## Version 2 (v2) Improvements Summary
#
# ### Changes from v1 to v2:
#
# 1. **Model Expansion (2 → 4-5 models)**
#    - Added XGBoost and LightGBM to the ensemble
#    - All models use appropriate preprocessing (OHE for Ridge, Ordinal for tree models)
#    - Graceful fallback if libraries are unavailable
#
# 2. **Hyperparameter Tuning with Optuna**
#    - Automated hyperparameter optimization for all models
#    - Reduced trials (10) and folds (3) during optimization for speed
#    - Full 5-fold CV for final OOF generation
#
# 3. **Feature Engineering**
#    - Added 4 derived features: `study_efficiency`, `sleep_study_ratio`, `total_engagement`, `study_hours_per_age`
#    - Captures non-linear relationships and normalized perspectives
#
# 4. **Enhanced Multi-Model Blending**
#    - Replaced 2-model analytical solution with scipy.optimize for N models
#    - Constrained optimization ensures weights sum to 1.0
#
# ### Performance Tracking:
# - Baseline (v1): OOF RMSE ~8.82, Kaggle score 8.78741
# - Current (v2): See performance summary in Cell 9
# - All changes documented in `s6e1-studynote.md`

# %%
# Create submission file
sub = sample_sub.copy()

# Trust sample_submission column name (this may differ by competition)
pred_col = [c for c in sub.columns if c != ID_COL]
assert len(pred_col) == 1, f'sample_submission must have exactly 1 prediction column: {pred_col}'
pred_col = pred_col[0]

sub[pred_col] = blend_test

# Save next to the notebook / working directory (Kaggle-friendly)
out_path = Path('submission.csv')
sub.to_csv(out_path, index=False)

print('saved:', out_path.resolve())
display(sub.head())

# Quick check: id duplicates / shape
print('id duplicates in submission:', sub[ID_COL].duplicated().sum())
print('submission shape:', sub.shape)
# Out:
# saved: /kaggle/working/submission.csv
#        id  exam_score
# 0  630000   71.819400
# 1  630001   69.262980
# 2  630002   87.721831
# 3  630003   54.524428
# 4  630004   47.030931
# id duplicates in submission: 0
# submission shape: (270000, 2)
